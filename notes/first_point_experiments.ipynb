# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mal_manga_data = pd.read_csv("../datasets/manga.csv")

# %%
mal_anime_data = pd.read_csv("../datasets/anime.csv")

# %%
mal_manga_data
# Out:
#        manga_id                                            title      type  \
# 0             2                                          Berserk     manga
# 1            13                                        One Piece     manga
# 2          1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run     manga
# 3          4632                                   Oyasumi Punpun     manga
# 4            25                              Fullmetal Alchemist     manga
# ...         ...                                              ...       ...
# 64828    158691                            Raise wa Kimi no Mono     manga
# 64829    159388                         Ore to Basil no Automata     manga
# 64830    160296                                Happy Candy Virus     manga
# 64831    160604                         Suibu Yametai Hagino-san  one_shot
# 64832    158167                  Kidou Senshi Gundam F91 Prequel     manga
#
# ...

# %%
mal_manga_data.columns
# Out:
# Index(['manga_id', 'title', 'type', 'score', 'scored_by', 'status', 'volumes',
#        'chapters', 'start_date', 'end_date', 'members', 'favorites', 'sfw',
#        'approved', 'created_at_before', 'updated_at', 'real_start_date',
#        'real_end_date', 'genres', 'themes', 'demographics', 'authors',
#        'serializations', 'synopsis', 'background', 'main_picture', 'url',
#        'title_english', 'title_japanese', 'title_synonyms'],
#       dtype='object')

# %% [markdown]
# Split into single and series

# %%
manga_series_filtered = mal_manga_data[mal_manga_data.type == "manga"]

# %%
doujinshi_series_filtered = mal_manga_data[mal_manga_data.type == "one_shot"]

# %%
manga_series_filtered
# Out:
#        manga_id                                              title   type  \
# 0             2                                            Berserk  manga
# 1            13                                          One Piece  manga
# 2          1706    JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga
# 3          4632                                     Oyasumi Punpun  manga
# 4            25                                Fullmetal Alchemist  manga
# ...         ...                                                ...    ...
# 64827    158089  Sukidarake Horoyoi Joshi to Icha Ero Dekichau:...  manga
# 64828    158691                              Raise wa Kimi no Mono  manga
# 64829    159388                           Ore to Basil no Automata  manga
# 64830    160296                                  Happy Candy Virus  manga
# 64832    158167                    Kidou Senshi Gundam F91 Prequel  manga
#
#        score  scored_by                status  volumes  chapters  start_date  \
# ...

# %%
doujinshi_series_filtered
# Out:
#        manga_id                                     title      type  score  \
# 99        48621                            Koe no Katachi  one_shot   8.39
# 251       92299                 Berserk: Shinen no Kami 2  one_shot   8.50
# 279      102165                                  Tokidoki  one_shot   8.03
# 416       17152                   One Piece: Strong World  one_shot   8.09
# 645      139152                  Bleach: Gokui Meimei-hen  one_shot   7.85
# ...         ...                                       ...       ...    ...
# 64772    150740                             Muteki Shoujo  one_shot    NaN
# 64773    150859                 Tsuki no Kirei na Yoru ni  one_shot    NaN
# 64788    156733               Kaseifu Kuma no Tsukino-san  one_shot    NaN
# 64802    121023  Siren No.46: Takeuchi Tamon Kenkyuu Note  one_shot    NaN
# 64831    160604                  Suibu Yametai Hagino-san  one_shot    NaN
#
# ...

# %%
doujinshi_series_filtered = doujinshi_series_filtered.drop(["type", "status"], axis = 1)

# %%
doujinshi_series_filtered
# Out:
#        manga_id                                     title  score  scored_by  \
# 99        48621                            Koe no Katachi   8.39      34205
# 251       92299                 Berserk: Shinen no Kami 2   8.50       8862
# 279      102165                                  Tokidoki   8.03      27250
# 416       17152                   One Piece: Strong World   8.09       8633
# 645      139152                  Bleach: Gokui Meimei-hen   7.85       7678
# ...         ...                                       ...    ...        ...
# 64772    150740                             Muteki Shoujo    NaN          1
# 64773    150859                 Tsuki no Kirei na Yoru ni    NaN          0
# 64788    156733               Kaseifu Kuma no Tsukino-san    NaN          0
# 64802    121023  Siren No.46: Takeuchi Tamon Kenkyuu Note    NaN          1
# 64831    160604                  Suibu Yametai Hagino-san    NaN          0
#
# ...
